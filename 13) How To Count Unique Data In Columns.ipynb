# %%
import pandas as pd
import numpy as np
my_df = pd.read_csv("all_years.csv")
my_df
# Out:
#       Year   Dog_name                          Breed          Gender  \
# 0     2008      ALFIE           JACK RUSSELL TERRIER    DESEXED MALE
# 1     2008      ALICE               FOX TERRIER WIRE  DESEXED FEMALE
# 2     2008  ARCHIBALD      GERMAN SHEPHERD DOG CROSS    DESEXED MALE
# 3     2008     Archie               AIREDALE TERRIER            MALE
# 4     2008     ARCHIE                            PUG            MALE
# ...    ...        ...                            ...             ...
# 1889  2012        ZOE            GERMAN SHEPHERD DOG  DESEXED FEMALE
# 1890  2012      ZOOEY                          BOXER          FEMALE
# 1891  2012    ZSA ZSA                     POMERANIAN          FEMALE
# 1892  2012    ZSA ZSA  CAVALIER KING CHARLES SPANIEL          FEMALE
# 1893  2012    ZSA ZSA  CAVALIER KING CHARLES SPANIEL          FEMALE
#
#               Suburb
# 0     NORTH ADELAIDE
# 1     NORTH ADELAIDE
# 2     NORTH ADELAIDE
# 3     NORTH ADELAIDE
# 4     NORTH ADELAIDE
# ...

# %%
# Grab a spesific column
my_df["Dog_name"]
# Out:
# 0           ALFIE
# 1           ALICE
# 2       ARCHIBALD
# 3          Archie
# 4          ARCHIE
#           ...
# 1889          ZOE
# 1890        ZOOEY
# 1891      ZSA ZSA
# 1892      ZSA ZSA
# 1893      ZSA ZSA
# Name: Dog_name, Length: 1894, dtype: object

# %%
# Count Values
my_df["Dog_name"].value_counts()
# Pass as DataFrame
pd.DataFrame(my_df["Dog_name"].value_counts())
# Out:
#                     count
# Dog_name
# MAX                    56
# CHARLIE                32
# JACK                   27
# RALPH                  25
# LUCY                   25
# ...                   ...
# HUTCHI COOPE-BAKER      1
# JAZ                     1
# BABY                    1
# JESSY                   1
# ZOOEY                   1
#
# [366 rows x 1 columns]

# %%
# Grab Uniques
my_df["Dog_name"].unique()
# Out:
# array(['ALFIE', 'ALICE', 'ARCHIBALD', 'Archie', 'ARCHIE', 'ARNIE',
#        'ARTIE', 'ASTRO', 'BAILY', 'BEAR', 'BELLA', 'BERTIE', 'BLACKIE',
#        'BLUSH', 'BOB', 'BOBBY', 'BODHI JODOCUS', 'BODRI', 'BOO',
#        'BRIDGET', 'BUFFY', 'CALLY', 'CELESTE', 'CHARLIE', 'CHARLIOTTE',
#        'CHI CHI', 'CHLOE', 'CLAIRE', 'Cleo', 'CLEO', 'COCO', 'COMET',
#        'COOPER', 'COW BOY', 'CRUMPET', 'DAISY', 'DARLA', 'DIEGO',
#        'DIZZIE', 'DOTTI', 'DOUGAL', 'DUDLEY', 'EDDIE', 'ELI CASH', 'ELLA',
#        'ETOSHA', 'EVIE', 'FERGUS', 'FIDEL', 'FINN', 'FIZZ', 'FRANK',
#        'FRECKLES', 'GEORGIA', 'GEORGIO', 'GOSSIP', 'GUS', 'GWYNETH',
#        'GYPSY', 'HARRY', 'HEIDI', 'HENRY', 'HETTY', 'HUGO', 'IKE', 'ILLY',
#        'ISABELLA', 'IVY', 'JACK', 'JAKE', 'JASPER', 'JAZZ', 'JESSE',
#        'JESSIE', 'JILLY', 'JIMMY', 'JOEY', 'KAHLA', 'KATIE', 'KIP',
#        'KOOKI', 'LEO', 'LILLI', 'LILLIE', 'LILLY', 'LITTLE BEAN', 'LOBY',
#        'LOLLY', 'LOUISE', 'LUCKY', 'LUCY', 'LULU', 'LUNA',
# ...

# %%
# Show as DataFrame
pd.DataFrame(my_df["Dog_name"].unique())
# Out:
#              0
# 0        ALFIE
# 1        ALICE
# 2    ARCHIBALD
# 3       Archie
# 4       ARCHIE
# ..         ...
# 361       TENA
# 362       TIRO
# 363   TOBUSCUS
# 364     WOMBLE
# 365      ZOOEY
#
# [366 rows x 1 columns]

# %%
pd.DataFrame(my_df["Dog_name"].unique()).head(50)
# Out:
#                 0
# 0           ALFIE
# 1           ALICE
# 2       ARCHIBALD
# 3          Archie
# 4          ARCHIE
# 5           ARNIE
# 6           ARTIE
# 7           ASTRO
# 8           BAILY
# 9            BEAR
# 10          BELLA
# 11         BERTIE
# 12        BLACKIE
# 13          BLUSH
# 14            BOB
# 15          BOBBY
# 16  BODHI JODOCUS
# 17          BODRI
# 18            BOO
# 19        BRIDGET
# 20          BUFFY
# 21          CALLY
# 22        CELESTE
# 23        CHARLIE
# 24     CHARLIOTTE
# 25        CHI CHI
# 26          CHLOE
# 27         CLAIRE
# 28           Cleo
# 29           CLEO
# 30           COCO
# 31          COMET
# 32         COOPER
# 33        COW BOY
# 34        CRUMPET
# 35          DAISY
# 36          DARLA
# 37          DIEGO
# 38         DIZZIE
# 39          DOTTI
# 40         DOUGAL
# 41         DUDLEY
# 42          EDDIE
# 43       ELI CASH
# 44           ELLA
# 45         ETOSHA
# 46           EVIE
# 47         FERGUS
# 48          FIDEL
# ...
