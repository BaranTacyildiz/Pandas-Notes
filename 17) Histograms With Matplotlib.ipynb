# %%
import pandas as pd
import numpy as np
from numpy.random import randn
# %matplotlib inline

# Create a quick dataFrame
my_df = pd.DataFrame(randn(100,4),columns = ["Mon","Tues","Wed","Thur"])
my_df
# Out:
#          Mon      Tues       Wed      Thur
# 0   1.426943  0.487478 -1.012577 -0.327520
# 1  -1.089754 -2.349608  0.056663 -0.932196
# 2   1.098384 -0.262769 -0.969321  0.483973
# 3  -0.419273  1.732316 -0.030414  0.119329
# 4   0.094835  0.776882  0.404580 -1.617064
# ..       ...       ...       ...       ...
# 95 -1.105266  1.551681  1.473702 -0.880756
# 96  1.263031  0.721417  1.356126  1.071461
# 97 -0.579449  2.156349 -0.011656  0.192208
# 98 -0.287826 -0.551409  0.287319  0.515741
# 99 -0.119178 -1.534776  1.927197 -0.967789
#
# [100 rows x 4 columns]

# %%
# Histogram
my_df["Wed"].hist()
# Out:
# <Axes: >

# %%
# Histogram with smaller bins,50 ,20 (bin = kutu)
my_df["Wed"].hist(bins=20)
# Out:
# <Axes: >

# %%
# Another way without grid bars
my_df["Wed"].plot(kind="hist",bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# plot(legend=)
my_df["Wed"].plot(kind="hist",bins=20,legend = True)
# Out:
# <Axes: ylabel='Frequency'>
