# %%
import pandas as pd 
import numpy as np

# %%
my_df = pd.read_csv('all_years.csv')
my_df
# Out:
#       Year   Dog_name                          Breed          Gender  \
# 0     2008      ALFIE           JACK RUSSELL TERRIER    DESEXED MALE
# 1     2008      ALICE               FOX TERRIER WIRE  DESEXED FEMALE
# 2     2008  ARCHIBALD      GERMAN SHEPHERD DOG CROSS    DESEXED MALE
# 3     2008     Archie               AIREDALE TERRIER            MALE
# 4     2008     ARCHIE                            PUG            MALE
# ...    ...        ...                            ...             ...
# 1889  2012        ZOE            GERMAN SHEPHERD DOG  DESEXED FEMALE
# 1890  2012      ZOOEY                          BOXER          FEMALE
# 1891  2012    ZSA ZSA                     POMERANIAN          FEMALE
# 1892  2012    ZSA ZSA  CAVALIER KING CHARLES SPANIEL          FEMALE
# 1893  2012    ZSA ZSA  CAVALIER KING CHARLES SPANIEL          FEMALE
#
#               Suburb
# 0     NORTH ADELAIDE
# 1     NORTH ADELAIDE
# 2     NORTH ADELAIDE
# 3     NORTH ADELAIDE
# 4     NORTH ADELAIDE
# ...              ...
# 1889  NORTH ADELAIDE
# 1890  NORTH ADELAIDE
# 1891        ADELAIDE
# 1892        ADELAIDE
# 1893  NORTH ADELAIDE
#
# [1894 rows x 5 columns]

# %%
#grab first 5 rows
my_df.head()
# Out:
#    Year   Dog_name                      Breed          Gender          Suburb
# 0  2008      ALFIE       JACK RUSSELL TERRIER    DESEXED MALE  NORTH ADELAIDE
# 1  2008      ALICE           FOX TERRIER WIRE  DESEXED FEMALE  NORTH ADELAIDE
# 2  2008  ARCHIBALD  GERMAN SHEPHERD DOG CROSS    DESEXED MALE  NORTH ADELAIDE
# 3  2008     Archie           AIREDALE TERRIER            MALE  NORTH ADELAIDE
# 4  2008     ARCHIE                        PUG            MALE  NORTH ADELAIDE

# %%
#grab certain number of first rows
my_df.head(9)
# Out:
#    Year   Dog_name                       Breed          Gender          Suburb
# 0  2008      ALFIE        JACK RUSSELL TERRIER    DESEXED MALE  NORTH ADELAIDE
# 1  2008      ALICE            FOX TERRIER WIRE  DESEXED FEMALE  NORTH ADELAIDE
# 2  2008  ARCHIBALD   GERMAN SHEPHERD DOG CROSS    DESEXED MALE  NORTH ADELAIDE
# 3  2008     Archie            AIREDALE TERRIER            MALE  NORTH ADELAIDE
# 4  2008     ARCHIE                         PUG            MALE  NORTH ADELAIDE
# 5  2008     ARCHIE                         PUG            MALE  NORTH ADELAIDE
# 6  2008      ARNIE  STAFFORDSHIRE BULL TERRIER    DESEXED MALE  NORTH ADELAIDE
# 7  2008      ARTIE           TERRIER - UNKNOWN    DESEXED MALE        ADELAIDE
# 8  2008      ARTIE           TERRIER - UNKNOWN    DESEXED MALE        ADELAIDE

# %%
#grab last 5 rows
my_df.tail()
# Out:
#       Year Dog_name                          Breed          Gender  \
# 1889  2012      ZOE            GERMAN SHEPHERD DOG  DESEXED FEMALE
# 1890  2012    ZOOEY                          BOXER          FEMALE
# 1891  2012  ZSA ZSA                     POMERANIAN          FEMALE
# 1892  2012  ZSA ZSA  CAVALIER KING CHARLES SPANIEL          FEMALE
# 1893  2012  ZSA ZSA  CAVALIER KING CHARLES SPANIEL          FEMALE
#
#               Suburb
# 1889  NORTH ADELAIDE
# 1890  NORTH ADELAIDE
# 1891        ADELAIDE
# 1892        ADELAIDE
# 1893  NORTH ADELAIDE

# %%
#grab certain number of last rows
my_df.tail(9)
# Out:
#       Year Dog_name                          Breed          Gender  \
# 1885  2012    ZELLA                     ROTTWEILER  DESEXED FEMALE
# 1886  2012      ZEP  CAVALIER KING CHARLES SPANIEL            MALE
# 1887  2012     ZEUS           FOX TERRIER (SMOOTH)            MALE
# 1888  2012      ZOE               POODLE MINIATURE  DESEXED FEMALE
# 1889  2012      ZOE            GERMAN SHEPHERD DOG  DESEXED FEMALE
# 1890  2012    ZOOEY                          BOXER          FEMALE
# 1891  2012  ZSA ZSA                     POMERANIAN          FEMALE
# 1892  2012  ZSA ZSA  CAVALIER KING CHARLES SPANIEL          FEMALE
# 1893  2012  ZSA ZSA  CAVALIER KING CHARLES SPANIEL          FEMALE
#
#               Suburb
# 1885  NORTH ADELAIDE
# 1886  NORTH ADELAIDE
# 1887  NORTH ADELAIDE
# 1888  NORTH ADELAIDE
# 1889  NORTH ADELAIDE
# 1890  NORTH ADELAIDE
# 1891        ADELAIDE
# 1892        ADELAIDE
# 1893  NORTH ADELAIDE

# %%
#get info about the dataframe
my_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1894 entries, 0 to 1893
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Year      1894 non-null   int64
#  1   Dog_name  1894 non-null   object
#  2   Breed     1894 non-null   object
#  3   Gender    1894 non-null   object
#  4   Suburb    1894 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 74.1+ KB

# %%
#get shape of rows and columns
my_df.shape
# Out:
# (1894, 5)

# %%
#get number of dimensions
my_df.ndim
# Out:
# 2

# %%
#get the column dataTypes
my_df.dtypes
# Out:
# Year         int64
# Dog_name    object
# Breed       object
# Gender      object
# Suburb      object
# dtype: object

# %%
#get some statistics about the data
my_df.describe()
# Out:
#               Year
# count  1894.000000
# mean   2010.406019
# std       1.374581
# min    2008.000000
# 25%    2009.000000
# 50%    2011.000000
# 75%    2012.000000
# max    2012.000000

# %%
#describe a spesific column
my_df['Gender'].describe()
# Out:
# count               1894
# unique                 4
# top       DESEXED FEMALE
# freq                 638
# Name: Gender, dtype: object

# %%
#get spesific columnd using brackets
my_df['Dog_name']
# Out:
# 0           ALFIE
# 1           ALICE
# 2       ARCHIBALD
# 3          Archie
# 4          ARCHIE
#           ...
# 1889          ZOE
# 1890        ZOOEY
# 1891      ZSA ZSA
# 1892      ZSA ZSA
# 1893      ZSA ZSA
# Name: Dog_name, Length: 1894, dtype: object

# %%
#select spesific column using dot notation
my_df.Dog_name
# Out:
# 0           ALFIE
# 1           ALICE
# 2       ARCHIBALD
# 3          Archie
# 4          ARCHIE
#           ...
# 1889          ZOE
# 1890        ZOOEY
# 1891      ZSA ZSA
# 1892      ZSA ZSA
# 1893      ZSA ZSA
# Name: Dog_name, Length: 1894, dtype: object

# %%
#select spesific column using location
my_df.iloc[:,1]
# : means all rows
# 1 means dog_name column
# Out:
# 0           ALFIE
# 1           ALICE
# 2       ARCHIBALD
# 3          Archie
# 4          ARCHIE
#           ...
# 1889          ZOE
# 1890        ZOOEY
# 1891      ZSA ZSA
# 1892      ZSA ZSA
# 1893      ZSA ZSA
# Name: Dog_name, Length: 1894, dtype: object
