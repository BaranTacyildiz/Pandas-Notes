# %%
import pandas as pd
import numpy as np
my_df = pd.read_csv("all_years_short.csv")
my_df
# Out:
#    Year   Dog_name                      Breed          Gender          Suburb
# 0  2008      ALFIE       JACK RUSSELL TERRIER    DESEXED MALE  NORTH ADELAIDE
# 1  2009      ALICE           FOX TERRIER WIRE  DESEXED FEMALE  NORTH ADELAIDE
# 2  2010  ARCHIBALD  GERMAN SHEPHERD DOG CROSS    DESEXED MALE  NORTH ADELAIDE
# 3  2011     Archie           AIREDALE TERRIER            MALE  NORTH ADELAIDE
# 4  2012     ARCHIE                        PUG            MALE  NORTH ADELAIDE

# %%
# Create new column
my_df["Frame Header"] = ["Dog 1","Dog 2","Dog 3","Dog 4","Dog 5"]
my_df
# Out:
#    Year   Dog_name                      Breed          Gender          Suburb  \
# 0  2008      ALFIE       JACK RUSSELL TERRIER    DESEXED MALE  NORTH ADELAIDE
# 1  2009      ALICE           FOX TERRIER WIRE  DESEXED FEMALE  NORTH ADELAIDE
# 2  2010  ARCHIBALD  GERMAN SHEPHERD DOG CROSS    DESEXED MALE  NORTH ADELAIDE
# 3  2011     Archie           AIREDALE TERRIER            MALE  NORTH ADELAIDE
# 4  2012     ARCHIE                        PUG            MALE  NORTH ADELAIDE
#
#   Frame Header
# 0        Dog 1
# 1        Dog 2
# 2        Dog 3
# 3        Dog 4
# 4        Dog 5

# %%
# Set Index
my_df.set_index("Frame Header",inplace = True)
# remember if u do it permanently use inplace = True otherwise it is just for a moment

# %%
# Show DataFrame
my_df
# Out:
#               Year   Dog_name                      Breed          Gender  \
# Frame Header
# Dog 1         2008      ALFIE       JACK RUSSELL TERRIER    DESEXED MALE
# Dog 2         2009      ALICE           FOX TERRIER WIRE  DESEXED FEMALE
# Dog 3         2010  ARCHIBALD  GERMAN SHEPHERD DOG CROSS    DESEXED MALE
# Dog 4         2011     Archie           AIREDALE TERRIER            MALE
# Dog 5         2012     ARCHIE                        PUG            MALE
#
#                       Suburb
# Frame Header
# Dog 1         NORTH ADELAIDE
# Dog 2         NORTH ADELAIDE
# Dog 3         NORTH ADELAIDE
# Dog 4         NORTH ADELAIDE
# Dog 5         NORTH ADELAIDE

# %%
# Reset Index
my_df.reset_index(inplace=True)
# remember inplace = True

# %%
# Drop Column
my_df.drop("Frame Header",axis=1)
# again u can use inplace if u do it permanently
# Out:
#    Year   Dog_name                      Breed          Gender          Suburb
# 0  2008      ALFIE       JACK RUSSELL TERRIER    DESEXED MALE  NORTH ADELAIDE
# 1  2009      ALICE           FOX TERRIER WIRE  DESEXED FEMALE  NORTH ADELAIDE
# 2  2010  ARCHIBALD  GERMAN SHEPHERD DOG CROSS    DESEXED MALE  NORTH ADELAIDE
# 3  2011     Archie           AIREDALE TERRIER            MALE  NORTH ADELAIDE
# 4  2012     ARCHIE                        PUG            MALE  NORTH ADELAIDE
